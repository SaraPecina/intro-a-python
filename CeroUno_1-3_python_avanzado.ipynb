# %% [markdown]
# # Python avanzado y principios del desarrollo de software
#
# ### Operadores de comparación
#
# Todos los lenguajes de programación tienen operadores que sirven para hacer comparaciones entre una cosa y otra, de tal modo que podamos tomar decisiones y clasificar datos. Por ejemplo, si quiero saber si el usuario actual es menor de edad, puedo preguntar eso usando el comparador < o > (menor que, o mayor que):

# %%
edad_del_usuario = 21

mayoria_de_edad = 21


edad_del_usuario <= mayoria_de_edad
# Out:
# True

# %% [markdown]
# Para esto usamos también los operadores mayor o igual qué `>=` y menor o igual que `<=`.
#
# Para comparar si algo es igual a algo más usamos el operador `==`. Por ejemplo:

# %%
current_user = 'Jorge Perez'

'JorGE PeReZ'

usuario_buscado = 'jorge perez'

current_user != usuario_buscado
# Out:
# True

# %%
import datetime
now = datetime.datetime.now()

print(str(now))
# Out:
# 2018-11-07 10:33:36.358997

# %% [markdown]
# Para comparar que algo es diferente de usamos `!=`

# %%
edad_del_usuario = 17

mayoria_de_edad = 18


edad_del_usuario != mayoria_de_edad
# Out:
# True

# %% [markdown]
# Para más información sobre operadores de comparación [aquí](https://docs.python.org/3/reference/lexical_analysis.html#operators)

# %% [markdown]
# ### Control de flujo o Control Flow
#
# El control de flujo es la manera que tiene un lenguaje para encaminar la data por uno u otro lado según los requerimientos que tu necesites usando condiciones que pueden ayudarse de comparadores.
#
# Por ejemplo, si el usuario es mayor de edad, imprime: es mayor de edad.

# %%
edad_del_usuario = 17
mayoria_de_edad = 18

if edad_del_usuario >= mayoria_de_edad:
    print("es mayor de edad")

# %% [markdown]
# Podemos un bloque de código que se ejecute en caso de que la condición sea falsa usando un `else` statement:

# %%
edad_del_usuario = 21
mayoria_de_edad = 18

if edad_del_usuario >= mayoria_de_edad:
    print("es mayor de edad")
else:
    print("es menor de edad")
# Out:
# es mayor de edad

# %% [markdown]
# Incluso, podemos agregar una o más condiciones adicionales a la primer condicional usando `elif` statements:

# %%
edad_del_usuario = 18
mayoria_de_edad = 18

if edad_del_usuario > mayoria_de_edad:
    print("es mayor de edad")
elif edad_del_usuario == 18:
    print("tiene 18 años")
else:
    print("es menor de edad")
# Out:
# tiene 18 años

# %% [markdown]
# Los siguientes elif statements pueden usarse sobre otras características del dataset, por ejemplo, si este fuera un arreglo con otros datos como color de pelo, podría poner en un elif: si el `color de pelo` es igual a `rojo` y pasar otro bloque de código, e inclusive poner más de una condición por cada `if` o `elif`:

# %%
usuario = {"edad": 29, "pelo": "rojo", "nombre":"Ron Weasley"}

if usuario["edad"] > 10 and usuario["pelo"] == "rojo":
    print("debes ser un Weasley")
# Out:
# debes ser un Weasley

# %% [markdown]
# Del mismo modo, puedes usar not para tus condicionantes:

# %%
usuario = {"edad": 2, "pelo": "sin pelo", "nombre":"Voldemort"}

if usuario["edad"] < 10:
    print("no eres un Weasley")

# %% [markdown]
# ### Ahora, un ejercicio:

# %% [markdown]
# Usemos lo que hemos aprendido de flujo de control y condicionantes para clasificar la edad, supongamos que tienes encuestas de salud de una población amplia y quieres __clasificar__ a los encuestados según su edad para comenzar a hacer estadística. Para ello recopilaste el dato __Edad__. Los registros que tienes se parecen a estos de abajo, donde recopilas género, edad, cantidad de hijos, colonia, salario mensual, si padecen de diabetes:

# %%
encuestados = [['Femenino', 38, 2, "Nuevo Repueblo", "de 0 a 5,000", False], 
               ['Femenino', 19, 0, "Contry La silla", "de 10,000 a 15,000", False], 
               ['Masculino', 22, 1, "Fomerrey 22", "de 0 a 5,000", False], 
               ['Masculino', 70, 3, "Valle Verde", "de 5,000 a 7,000", True], 
               ['Femenino', 57, 4, "Centro", "de 7,000 a 10,000", False], 
               ['Femenino', 44, 0, "Valle Alto", "de 30,000 a 50,000", False], 
               ['Femenino', 20, 2, "Burócratas Municipales", "de 5,000 a 7,000", True], 
               ['Masculino', 19, 0, "Buenos Aires", "de 10,000 a 13,000", True], 
               ['Femenino', 12, 0, "Obrera", "de 5,000 a 7,000", True], 
               ['Masculino', 32, 3, "Contry Sol", "de 10,000 a 15,000", False], 
               ['Femenino', 87, 9, "Del Paseo", "de 15,000 a 20,000", True], 
               ['Femenino', 25, 1, "Roma", "de 20,000 a 25,000", False], 
               ['Masculino', 65, 3, "Estadio", "de 10,000 a 15,000", True], ]

# %% [markdown]
# Para clasificar las edades quiero usar una metodología de la universidad autónoma de tangamandapio que va así:

# %%
# Dificultad normal:

# edad mayor a 20: no-joven
# edad menor a 20: joven


# dificultad insanity:

rango_de_edades = { "joven": [10, 19], 
                    "millenial": [20, 35], 
                    "super adulto": [36, 300],
                  }

# %% [markdown]
# Agrega un último valor a cada registro que represente la clasificación según la edad. Usa un for loop, las comparaciones que consideres necesarias, los elifs que consideres necesarios y las dobles condicionales que consideres necesarias y append.
#
# __Input__: la variable encuestados y la clasificación normal, o la insanity
# __cómputo__: clasificar cada registro según la edad
# __output__: la lista con una columna más que represente esta clasificación

# %% [markdown]
# ### Funciones
#
# __¿Qué es una función?__

# %% [markdown]
# En python, como en muchos otros lenguajes, las funciones se __definen__ para encapsular un comportamiento o reutilizar código. Por ejemplo, en nuestro ejemplo de arriba para verificar la edad, es posible que tengamos que utilizarlo en el futuro. Para no re-escribirlo, definamos una función:

# %%
edad_del_usuario = 18


def checar_edad(usuario):
    mayoria_de_edad = 18
    if usuario > mayoria_de_edad:
        print("es mayor de edad")
    elif usuario == 18:
        print("tiene 18 años")
    else:
        print("es menor de edad")

def hola_hola():
    print("hola mundo")
        
checar_edad(edad_del_usuario)

hola_hola()
# Out:
# tiene 18 años
# hola mundo

# %% [markdown]
# ## Programación estructurada y modular
#
# Hasta ahora la mayoría de nuestro código lo hemos ejecutado en la consola, sin embargo, en cuanto cerramos la consola nuestro código, nuestras variables y nuestro trabajo desaparecen. Es por eso que cuando ya comenzamos a trabajar como científicas de datos, lo que requerimos hacer es guardar nuestro código en un archivo tipo python, al que le llamamos script. Cualquier archivo que termine en `.py` es un script de python y puede ser ejecutado con el intérprete de `python`.
#
# La programación que hacemos en un solo archivo, con un solo punto de salida arriba a abajo se llama programación estructurada y es el tipo de programación que hemos hecho hasta ahora. A medida que nuestro trabajo se vuelva más complejo vamos a requerir separar nuestro código en partes más pequeñas y trabajarlo por separado para aminorar las fallas y facilitar su manejo: recuerda, divide y vencerás. En desarrollo de software, dividir grandes problemas en problemas más y más chicos es la mejor manera de programar. Para ello existe la programación modular: donde nosotros agrupamos nuestro código en módulos, e incluso en archivos distintos para mandarlo llamar cuando así lo consideremos. Los programadores suelen además escribir sus propios módulos que usan frecuentemente y algunas veces, cuando es código muy extenso y necesario, el desarrollador lo distribuye como una librería.
#
# Para escribir y mandar a llamar un módulo:
#
# 1. definamos un archivo con el nombre del módulo y sus funciones adentro. Por ejemplo: modulo_de_nombres.py
# 2. mandemos a llamar ese archivo usando la función `import modulo_de_nombres`
# 3. dentro de ese nuevo documento podemos usar las funciones escribiendo modulo_de_nombres.nombre_de_función.
#
# Demostración.

# %% [markdown]
# ## Manipulación de strings
#
# Los strings pueden ser manipulados de muchas maneras, y ustedes como científicas de datos estarán manipulando strings muy comúnmente. Veamos algunos métodos.
#
# Accesando substrings:
#
# `a = '20180927'`
# `a[1:4]`
#
#
# __capitalize__
#
# str.capitalize() capitaliza el string
#
# __count__
#
# cuenta la cantidad de veces que ocurre el string que le pasas.
# str.count(string_a_buscar)
#
# __find__
#
# str.find(string_a_buscar) Retorna la posición en la que se encuentra el string buscado.
#
# __in__
#
# In retorna si el substring existe o no en el string.
#
# __replace__
#
# str.replace(old, new, count) regresa una copia del string, con los valores remplazados. Count es un argumento opcional para sólo reemplazar un número definido de veces.
#
# __split__
#
# str.split(delimitador, maxsplit=-1) regresa una lista con los strings separados por el delimitador. Max split es un argumento opcional para delimitar la cantidad de veces máxima que este delimitador será aplicado.
#
# [Aquí puedes ver la documentación de los strings.](https://docs.python.org/3.7/library/string.html)
#
# Update: esa no es tan buena, les agrego más:
#
# [La de python 2.5](https://docs.python.org/release/2.5.2/lib/string-methods.html)
# [Un tutorial](https://thehelloworldprogram.com/python/python-string-methods/)
#
#
# ### Ejercicio: Nombres y apellidos.
#
# A partir de la siguiente lista de nombres genera sublistas donde separes los dos apellidos del nombre, independientemente si la persona tiene uno o dos nombres.
#
# __input__: Lista de nombres y apellidos
# __cómputo__: separar los últimos dos apellidos en una sub-lista, y el nombre o nombres en otra sub-lista
# __output__: ejemplo `['Ana Gabriel González García], ['Gisel Martínez Cordero']` debe cambiar a `[['Ana Gabriel'], ['González García']], [['Gisel'], ['Martínez Cordero']]`

# %%
nombres = [
    'María del Rosario Estupiñan Hernández',
    'Ana Gabriela Martinez Martinez',
    'Gabriela Muñoz Pérez',
    'Claudia González Aguirre',
    'Denise Martínez Garcia',
    'Ana Karenina Macías Flores',
    'Roberta Pulido Díaz',
    'Yolanda Eréndira Ibarra Márquez',
    'Carmen Ochoa Escandón',
    'Josefina Salinas Martínez',
    'Hilda María Bañuelos Cortés',
    'Eunice Romero Garza',
    'María Margadalena Sanchez Sanchez',
    'Ana Carolina Junco Treviño',
    'Paula Ivette Durán Rosas',
    'Sandra Maldonado Barrón',
    'Amparo Armendáriz Ruiz',
    'Nadia Leticia Carranza Téllez',
    'Cinthia Ontiveros Garza'
]

# %% [markdown]
# ### Importando Numpy
#
# __Numpy__ es una librería estadística de python especialidada en arreglos (listas) multidimensionales. Justamente es un conjunto de módulos que alguien escribió para realizar funciones estadísticas porque se dio cuenta que era una actividad recurrente en su trabajo, y decidió escribir módulos y luego liberar su código para que los programadores del público lo mejoraran. Para importar `numpy` hay que tenerlo instalado y sólo indicar `import numpy` al principio de mi script.
#
# Juguemos con Numpy:

# %%
import numpy as np

a = [1, 2, 3]
b = [2, 3, 4]
print(a + b)

c = np.array(a)
d = np.array(b)

print(c + d)
print(c * d)
# Out:
# [1, 2, 3, 2, 3, 4]
# [3 5 7]
# [ 2  6 12]

# %%
encuestados_numpy = np.array(encuestados)
encuestados_numpy

print(type(encuestados))
print(encuestados_numpy)
# Out:
# <class 'list'>
# [['Femenino' 38 2 'Nuevo Repueblo' 'de 0 a 5,000' False 'joven']
#  ['Femenino' 19 0 'Contry La silla' 'de 10,000 a 15,000' False None]
#  ['Masculino' 22 1 'Fomerrey 22' 'de 0 a 5,000' False 'joven']
#  ['Masculino' 70 3 'Valle Verde' 'de 5,000 a 7,000' True 'joven']
#  ['Femenino' 57 4 'Centro' 'de 7,000 a 10,000' False 'joven']
#  ['Femenino' 44 0 'Valle Alto' 'de 30,000 a 50,000' False 'joven']
#  ['Femenino' 20 2 'Burócratas Municipales' 'de 5,000 a 7,000' True None]
#  ['Masculino' 19 0 'Buenos Aires' 'de 10,000 a 13,000' True None]
#  ['Femenino' 12 0 'Obrera' 'de 5,000 a 7,000' True None]
#  ['Masculino' 32 3 'Contry Sol' 'de 10,000 a 15,000' False 'joven']
#  ['Femenino' 87 9 'Del Paseo' 'de 15,000 a 20,000' True 'joven']
#  ['Femenino' 25 1 'Roma' 'de 20,000 a 25,000' False 'joven']
#  ['Masculino' 65 3 'Estadio' 'de 10,000 a 15,000' True 'joven']]

# %%
# forma del arreglo
encuestados_numpy.shape
# Out:
# (13, 7)

# %% [markdown]
# Test drive de Numpy [aquí](https://docs.scipy.org/doc/numpy/user/quickstart.html)

# %% [markdown]
# ### Leyendo archivos CSV
#
# Antes de procesar datos, una habilidad necesaria será la de leer datos en CSV y escribir datos nuevos. En el directorio hay un conjunto de datos llamado `declaratorias_emergencia_desastre.csv` estaremos trabjando con ese para abrirlo.
#
# La función de lectura con python empieza con la función open:
#
# file_object  = open(“filename”, “mode”)
#
# donde file_object es el nombre de la variable con la que vas a estar trabajando, "filename" es el nombre del archivo, y "mode" es el modo en el que estarás abriendo el archivo.
#
# __Modo__
#
# Hay tres modos de abrir el archivo, _lectura, escritura y añadidura_ representados por la letra "r", "w" y "a" respectivamente.
#
# __Lectura__ (Read) el archivo se abre en modo lectura y no se puede escribir en él.
# __Escritura__ (Write) abrimos el archivo y lo sobre-escribimos. Si tenía algo antes, se borrará.
# __Añadidura__ (Append) al igual que la función, este modo añade los datos que estás escribiendo al final del renglón, respetando lo que había antes.
#
# Si el archivo no existía, python lo crea, por lo que esta también es la forma de escribir el output de tus funciones.
#
#
# Ahora veamos un ejemplo de lectura:

# %%
file_object = open("declaratorias_emergencia_desastre.csv", "r")

print(file_object.read())
# Out:
# estado,municipio,clave_inegi,declaratoria_emergencia_ordinaria,declaratoria_emergencia_extraordinaria,declaratoria_desastre,magniud_sismo,fecha_evento
# Chiapas,Acacoyagua,07001,no aplica,sí,sí,8.2,2017-09-07
# Chiapas,Acala,07002,no aplica,sí,sí,8.2,2017-09-07
# Chiapas,
no aplica,sí,sí,7.1,2017-09-19
# Puebla,Huehuetlán el Grande,21150,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Santo Tomás Hueyotlipan,21151,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tecali de Herrera,21153,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tecamachalco,21154,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tecomatlán,21155,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tehuacán,21156,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tehuitzingo,21157,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Teopantlán,21159,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Teotlalco,21160,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepanco de López,21161,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepatlaxco de Hidalgo,21163,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepeaca,21164,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepemaxalco,21165,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepeojuma,21166,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepexco,21168,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepexi de Rodríguez,21169,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tepeyahualco de Cuauhtémoc,21171,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tianguismanalco,21175,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tilapa,21176,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tlacotepec de Benito Juárez,21177,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tlahuapan,21180,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tlaltenango,21181,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tlanepantla,21182,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tlapanalá,21185,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tochimilco,21188,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tochtepec,21189,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Totoltepec de Guerrero,21190,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tulcingo,21191,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Tzicatlacoyan,21193,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Xayacatlán de Bravo,21196,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Xicotlán,21198,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Xochiltepec,21201,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Xochitlán Todos Santos,21203,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Yehualtepec,21205,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Zacapala,21206,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Zapotitlán,21209,no aplica,sí,sí,7.1,2017-09-19
# Puebla,Zaragoza,21211,no aplica,sí,sí,7.1,2017-09-19
# Tlaxcala,Amaxac de Guerrero,29001,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Apetatitlán de Antonio Carvajal,29002,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Apizaco,29005,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Cuaxomulco,29009,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Chiautempan,29010,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Hueyotlipan,29014,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Ixtacuixtla de Mariano Matamoros,29015,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Mazatecochco de José María Morelos,29017,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Contla de Juan Cuamatzi,29018,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tepetitla de Lardizábal,29019,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Acuamanala de Miguel Hidalgo,29022,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Natívitas,29023,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Panotla,29024,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Pablo del Monte,29025,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Cruz Tlaxcala,29026,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tenancingo,29027,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Teolocholco,29028,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tepeyanco,29029,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tetlatlahuca,29032,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tlaxcala,29033,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Totolac,29036,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Tzompantepec,29038,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Xaltocan,29040,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Papalotla de Xicohténcatl,29041,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Xicohtzinco,29042,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Yauhquemehcan,29043,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Zacatelco,29044,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,La Magdalena Tlaltelulco,29048,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Damián Texóloc,29049,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Francisco Tetlanohcan,29050,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Jerónimo Zacualpan,29051,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San José Teacalco,29052,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Juan Huactzinco,29053,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Lorenzo Axocomanitla,29054,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,San Lucas Tecopilco,29055,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Ana Nopalucan,29056,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Apolonia Teacalco,29057,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Catarina Ayometla,29058,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Cruz Quilehtla,29059,no aplica,no aplica,sí,7.1,2017-09-19
# Tlaxcala,Santa Isabel Xiloxoxtla,29060,no aplica,no aplica,sí,7.1,2017-09-19
# Veracruz de Ignacio de la Llave,Coatzacoalcos,30039,no aplica,no aplica,sí,8.2,2017-09-07
# Veracruz de Ignacio de la Llave,Cosoleacaque,30048,no aplica,no aplica,sí,8.2,2017-09-07
# Veracruz de Ignacio de la Llave,Hidalgotitlán,30070,no aplica,no aplica,sí,8.2,2017-09-07
# Veracruz de Ignacio de la Llave,Jáltipan,30089,no aplica,no aplica,sí,8.2,2017-09-07
# Veracruz de Ignacio de la Llave,Minatitlán,30108,no aplica,no aplica,sí,8.2,2017-09-07
# Veracruz de Ignacio de la Llave,Texistepec,30172,no aplica,no aplica,sí,8.2,2017-09-07

# %% [markdown]
# Ahora veamos un ejemplo de escritura con un for loop

# %%
# print(encuestados)

# print(len(encuestados))

nuevo_archivo = open('nuevo_archivo.csv', 'w')

for encuestado in encuestados:
    for each in encuestado:
        nuevo_archivo.write(str(each) + ',')
    nuevo_archivo.write('\n')

nuevo_archivo.close()

nuevo_archivo = open('nuevo_archivo.csv', 'r')
        
print(nuevo_archivo.read())
# Out:
# Femenino,38,2,Nuevo Repueblo,de 0 a 5,000,False,joven,
# Femenino,19,0,Contry La silla,de 10,000 a 15,000,False,None,
# Masculino,22,1,Fomerrey 22,de 0 a 5,000,False,joven,
# Masculino,70,3,Valle Verde,de 5,000 a 7,000,True,joven,
# Femenino,57,4,Centro,de 7,000 a 10,000,False,joven,
# Femenino,44,0,Valle Alto,de 30,000 a 50,000,False,joven,
# Femenino,20,2,Burócratas Municipales,de 5,000 a 7,000,True,None,
# Masculino,19,0,Buenos Aires,de 10,000 a 13,000,True,None,
# Femenino,12,0,Obrera,de 5,000 a 7,000,True,None,
# Masculino,32,3,Contry Sol,de 10,000 a 15,000,False,joven,
# Femenino,87,9,Del Paseo,de 15,000 a 20,000,True,joven,
# Femenino,25,1,Roma,de 20,000 a 25,000,False,joven,
# Masculino,65,3,Estadio,de 10,000 a 15,000,True,joven,

# %%
print(len(encuestados))
print(len(encuestados[0]))


encuestados[0][1]
# Out:
# 13
# 7
# 38

# %%
import pandas as pd

alerta = pd.read_csv('declaratorias_emergencia_desastre.csv', sep=',')

alerta
# Out:
#                               estado                  municipio  clave_inegi  \
# 0                            Chiapas                 Acacoyagua         7001
# 1                            Chiapas                      Acala         7002
# 2                            Chiapas                 Acapetahua         7003
# 3                            Chiapas                 Altamirano         7004
# 4                            Chiapas                     Amatán         7005
# 5                            Chiapas  Amatenango de la Frontera         7006
# 6                            Chiapas       Amatenango del Valle         7007
# 7                            Chiapas         Angel Albino Corzo         7008
# 8                            Chiapas                    Arriaga         7009
# 9                            Chiapas          Bejucal de Ocampo         7010
# 10                           Chiapas                Bella Vista         7011
# 11                           Chiapas                Berriozábal         7012
# 12                           Chiapas                     Bochil         7013
# 13                           Chiapas                  El Bosque         7014
# 14                           Chiapas                 Cacahoatán         7015
# 15                           Chiapas                   Catazajá         7016
# 16                           Chiapas                  Cintalapa         7017
# 17                           Chiapas                   Coapilla         7018
# 18                           Chiapas       Comitán de Domínguez         7019
# 19                           Chiapas               La Concordia         7020
# 20                           Chiapas                  Copainalá         7021
# 21                           Chiapas              Chalchihuitán         7022
# 22                           Chiapas                    Chamula         7023
# 23                           Chiapas                     Chanal         7024
# 24                           Chiapas              Chapultenango         7025
# 25                           Chiapas                   Chenalhó         7026
# 26                           Chiapas            Chiapa de Corzo         7027
# 27                           Chiapas                  Chiapilla         7028
# 28                           Chiapas                  Chicoasén         7029
# 29                           Chiapas                Chicomuselo         7030
# ..                               ...                        ...          ...
# 695                         Tlaxcala                Teolocholco        29028
# 696                         Tlaxcala                  Tepeyanco        29029
# 697                         Tlaxcala               Tetlatlahuca        29032
# 698                         Tlaxcala                   Tlaxcala        29033
# 699                         Tlaxcala                    Totolac        29036
# 700                         Tlaxcala               Tzompantepec        29038
# 701                         Tlaxcala                   Xaltocan        29040
# 702                         Tlaxcala  Papalotla de Xicohténcatl        29041
# 703                         Tlaxcala                Xicohtzinco        29042
# 704                         Tlaxcala              Yauhquemehcan        29043
# 705                         Tlaxcala                  Zacatelco        29044
# 706                         Tlaxcala   La Magdalena Tlaltelulco        29048
# 707                         Tlaxcala         San Damián Texóloc        29049
# 708                         Tlaxcala  San Francisco Tetlanohcan        29050
# 709                         Tlaxcala     San Jerónimo Zacualpan        29051
# 710                         Tlaxcala          San José Teacalco        29052
# 711                         Tlaxcala        San Juan Huactzinco        29053
# 712                         Tlaxcala   San Lorenzo Axocomanitla        29054
# 713                         Tlaxcala        San Lucas Tecopilco        29055
# 714                         Tlaxcala        Santa Ana Nopalucan        29056
# 715                         Tlaxcala    Santa Apolonia Teacalco        29057
# 716                         Tlaxcala    Santa Catarina Ayometla        29058
# 717                         Tlaxcala       Santa Cruz Quilehtla        29059
# 718                         Tlaxcala    Santa Isabel Xiloxoxtla        29060
# 719  Veracruz de Ignacio de la Llave              Coatzacoalcos        30039
# 720  Veracruz de Ignacio de la Llave               Cosoleacaque        30048
# 721  Veracruz de Ignacio de la Llave              Hidalgotitlán        30070
# 722  Veracruz de Ignacio de la Llave                   Jáltipan        30089
# 723  Veracruz de Ignacio de la Llave                 Minatitlán        30108
# 724  Veracruz de Ignacio de la Llave                 Texistepec        30172
#
#     declaratoria_emergencia_ordinaria declaratoria_emergencia_extraordinaria  \
# 0                           no aplica                                     sí
# 1                           no aplica                                     sí
# 2                           no aplica                                     sí
# 3                           no aplica                                     sí
# 4                           no aplica                                     sí
# 5                           no aplica                                     sí
# 6                           no aplica                                     sí
# 7                           no aplica                                     sí
# 8                           no aplica                                     sí
# 9                           no aplica                                     sí
# 10                          no aplica                                     sí
# 11                          no aplica                                     sí
# 12                          no aplica                                     sí
# 13                          no aplica                                     sí
# 14                          no aplica                                     sí
# 15                          no aplica                                     sí
# 16                          no aplica                                     sí
# 17                          no aplica                                     sí
# 18                          no aplica                                     sí
# 19                          no aplica                                     sí
# 20                          no aplica                                     sí
# 21                          no aplica                                     sí
# 22                          no aplica                                     sí
# 23                          no aplica                                     sí
# 24                          no aplica                                     sí
# 25                          no aplica                                     sí
# 26                          no aplica                                     sí
# 27                          no aplica                                     sí
# 28                          no aplica                                     sí
# 29                          no aplica                                     sí
# ..                                ...                                    ...
# 695                         no aplica                              no aplica
# 696                         no aplica                              no aplica
# 697                         no aplica                              no aplica
# 698                         no aplica                              no aplica
# 699                         no aplica                              no aplica
# 700                         no aplica                              no aplica
# 701                         no aplica                              no aplica
# 702                         no aplica                              no aplica
# 703                         no aplica                              no aplica
# 704                         no aplica                              no aplica
# 705                         no aplica                              no aplica
# 706                         no aplica                              no aplica
# 707                         no aplica                              no aplica
# 708                         no aplica                              no aplica
# 709                         no aplica                              no aplica
# 710                         no aplica                              no aplica
# 711                         no aplica                              no aplica
# 712                         no aplica                              no aplica
# 713                         no aplica                              no aplica
# 714                         no aplica                              no aplica
# 715                         no aplica                              no aplica
# 716                         no aplica                              no aplica
# 717                         no aplica                              no aplica
# 718                         no aplica                              no aplica
# 719                         no aplica                              no aplica
# 720                         no aplica                              no aplica
# 721                         no aplica                              no aplica
# 722                         no aplica                              no aplica
# 723                         no aplica                              no aplica
# 724                         no aplica                              no aplica
#
#     declaratoria_desastre  magniud_sismo fecha_evento
# 0                      sí            8.2   2017-09-07
# 1                      sí            8.2   2017-09-07
# 2                      sí            8.2   2017-09-07
# 3                      sí            8.2   2017-09-07
# 4                      sí            8.2   2017-09-07
# 5                      sí            8.2   2017-09-07
# 6                      sí            8.2   2017-09-07
# 7                      sí            8.2   2017-09-07
# 8                      sí            8.2   2017-09-07
# 9                      sí            8.2   2017-09-07
# 10                     sí            8.2   2017-09-07
# 11                     sí            8.2   2017-09-07
# 12                     sí            8.2   2017-09-07
# 13                     sí            8.2   2017-09-07
# 14                     sí            8.2   2017-09-07
# 15              no aplica            8.2   2017-09-07
# 16                     sí            8.2   2017-09-07
# 17                     sí            8.2   2017-09-07
# 18                     sí            8.2   2017-09-07
# 19                     sí            8.2   2017-09-07
# 20                     sí            8.2   2017-09-07
# 21                     sí            8.2   2017-09-07
# 22                     sí            8.2   2017-09-07
# 23                     sí            8.2   2017-09-07
# 24              no aplica            8.2   2017-09-07
# 25                     sí            8.2   2017-09-07
# 26                     sí            8.2   2017-09-07
# 27                     sí            8.2   2017-09-07
# 28                     sí            8.2   2017-09-07
# 29                     sí            8.2   2017-09-07
# ..                    ...            ...          ...
# 695                    sí            7.1   2017-09-19
# 696                    sí            7.1   2017-09-19
# 697                    sí            7.1   2017-09-19
# 698                    sí            7.1   2017-09-19
# 699                    sí            7.1   2017-09-19
# 700                    sí            7.1   2017-09-19
# 701                    sí            7.1   2017-09-19
# 702                    sí            7.1   2017-09-19
# 703                    sí            7.1   2017-09-19
# 704                    sí            7.1   2017-09-19
# 705                    sí            7.1   2017-09-19
# 706                    sí            7.1   2017-09-19
# 707                    sí            7.1   2017-09-19
# 708                    sí            7.1   2017-09-19
# 709                    sí            7.1   2017-09-19
# 710                    sí            7.1   2017-09-19
# 711                    sí            7.1   2017-09-19
# 712                    sí            7.1   2017-09-19
# 713                    sí            7.1   2017-09-19
# 714                    sí            7.1   2017-09-19
# 715                    sí            7.1   2017-09-19
# 716                    sí            7.1   2017-09-19
# 717                    sí            7.1   2017-09-19
# 718                    sí            7.1   2017-09-19
# 719                    sí            8.2   2017-09-07
# 720                    sí            8.2   2017-09-07
# 721                    sí            8.2   2017-09-07
# 722                    sí            8.2   2017-09-07
# 723                    sí            8.2   2017-09-07
# 724                    sí            8.2   2017-09-07
#
# [725 rows x 8 columns]

# %%
# imprimiento los primeros datos

alerta.head()
# Out:
#     estado   municipio  clave_inegi declaratoria_emergencia_ordinaria  \
# 0  Chiapas  Acacoyagua         7001                         no aplica
# 1  Chiapas       Acala         7002                         no aplica
# 2  Chiapas  Acapetahua         7003                         no aplica
# 3  Chiapas  Altamirano         7004                         no aplica
# 4  Chiapas      Amatán         7005                         no aplica
#
#   declaratoria_emergencia_extraordinaria declaratoria_desastre  magniud_sismo  \
# 0                                     sí                    sí            8.2
# 1                                     sí                    sí            8.2
# 2                                     sí                    sí            8.2
# 3                                     sí                    sí            8.2
# 4                                     sí                    sí            8.2
#
#   fecha_evento
# 0   2017-09-07
# 1   2017-09-07
# 2   2017-09-07
# 3   2017-09-07
# 4   2017-09-07

# %%
# imprimiendo los últimos datos

alerta.tail()
# Out:
#                               estado      municipio  clave_inegi  \
# 720  Veracruz de Ignacio de la Llave   Cosoleacaque        30048
# 721  Veracruz de Ignacio de la Llave  Hidalgotitlán        30070
# 722  Veracruz de Ignacio de la Llave       Jáltipan        30089
# 723  Veracruz de Ignacio de la Llave     Minatitlán        30108
# 724  Veracruz de Ignacio de la Llave     Texistepec        30172
#
#     declaratoria_emergencia_ordinaria declaratoria_emergencia_extraordinaria  \
# 720                         no aplica                              no aplica
# 721                         no aplica                              no aplica
# 722                         no aplica                              no aplica
# 723                         no aplica                              no aplica
# 724                         no aplica                              no aplica
#
#     declaratoria_desastre  magniud_sismo fecha_evento
# 720                    sí            8.2   2017-09-07
# 721                    sí            8.2   2017-09-07
# 722                    sí            8.2   2017-09-07
# 723                    sí            8.2   2017-09-07
# 724                    sí            8.2   2017-09-07

# %%
print(type(alerta))


# imprimiendo las columnas

print(alerta.columns)
print()
# imprimiendo los tipos de columnas

print(alerta.dtypes)
print()

# imprimiento los valores en una lista
print(alerta.values)
print()

# obteniendo una descripción general de los datos

print(alerta.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['estado', 'municipio', 'clave_inegi',
#        'declaratoria_emergencia_ordinaria',
#        'declaratoria_emergencia_extraordinaria', 'declaratoria_desastre',
#        'magniud_sismo', 'fecha_evento'],
#       dtype='object')
#
# estado                                     object
# municipio                                  object
# clave_inegi                                 int64
# declaratoria_emergencia_ordinaria          object
# declaratoria_emergencia_extraordinaria     object
# declaratoria_desastre                      object
# magniud_sismo                             float64
# fecha_evento                               object
# dtype: object
#
# [['Chiapas' 'Acacoyagua' 7001 ... 'sí' 8.2 '2017-09-07']
#  ['Chiapas' 'Acala' 7002 ... 'sí' 8.2 '2017-09-07']
#  ['Chiapas' 'Acapetahua' 7003 ... 'sí' 8.2 '2017-09-07']
#  ...
#  ['Veracruz de Ignacio de la Llave' 'Jáltipan' 30089 ... 'sí' 8.2
#   '2017-09-07']
#  ['Veracruz de Ignacio de la Llave' 'Minatitlán' 30108 ... 'sí' 8.2
#   '2017-09-07']
#  ['Veracruz de Ignacio de la Llave' 'Texistepec' 30172 ... 'sí' 8.2
#   '2017-09-07']]
#
#         clave_inegi  magniud_sismo
# count    725.000000     725.000000
# mean   18069.477241       7.732690
# std     5915.128568       0.544124
# min     7001.000000       7.100000
# 25%    17014.000000       7.100000
# 50%    20254.000000       8.200000
# 75%    20538.000000       8.200000
# max    30172.000000       8.200000

# %%
alerts.groupby('estado').mean()
# Out:
#                                   clave_inegi  magniud_sismo
# estado
# CIudad de México                  9009.500000       7.100000
# Chiapas                           7061.247934       8.200000
# Guerrero                         12036.315789       7.100000
# Morelos                          17017.000000       7.100000
# México                           15066.250000       7.100000
# Oaxaca                           20285.620219       7.971585
# Puebla                           21110.125000       7.100000
# Tlaxcala                         29034.125000       7.100000
# Veracruz de Ignacio de la Llave  30087.666667       8.200000

# %% [markdown]
# Prueba de manejo de pandas [aquí](http://pandas.pydata.org/pandas-docs/stable/10min.html)
